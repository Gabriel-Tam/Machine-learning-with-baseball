# %% [markdown]
# # Get data from MLB API

# %%
# Get data form MLB API

from pybaseball import pitching_stats

START = 2017
END = 2023

pitching = pitching_stats(START,END, qual= 30)

# %%
from util import search_row

# %%
type(pitching)
# Out:
# pandas.core.frame.DataFrame

# %%
pitching.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2963 entries, 46 to 2726
# Columns: 393 entries, IDfg to Pit+ FO
# dtypes: float64(325), int64(64), object(4)
# memory usage: 8.9+ MB

# %%
pitching.head()
# Out:
#       IDfg  Season           Name Team  Age   W  L  WAR   ERA   G  ...  \
# 46   10954    2018   Jacob deGrom  NYM   30  10  9  9.0  1.70  32  ...
# 470  10603    2017     Chris Sale  BOS   28  17  8  7.6  2.90  32  ...
# 252  13125    2019    Gerrit Cole  HOU   28  20  5  7.5  2.50  33  ...
# 262   3137    2018   Max Scherzer  WSN   33  18  7  7.5  2.53  33  ...
# 211  19361    2021  Corbin Burnes  MIL   26  11  5  7.5  2.43  28  ...
#
#      Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  \
# 46       NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 470      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 252      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 262      NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 211    114.0      NaN      NaN      NaN   133.0      104.0      112.0
#
#      Stf+ FO  Loc+ FO  Pit+ FO
# 46       NaN      NaN      NaN
# 470      NaN      NaN      NaN
# ...

# %% [markdown]
# Searching a only player by name

# %%
search = search_row(pitching, ['Name'], 'Max Scherzer')
search
# Out:
#       IDfg  Season          Name   Team  Age   W  L  WAR   ERA   G  ...  \
# 262   3137    2018  Max Scherzer    WSN   33  18  7  7.5  2.53  33  ...
# 486   3137    2019  Max Scherzer    WSN   34  11  7  6.5  2.92  27  ...
# 256   3137    2017  Max Scherzer    WSN   32  16  6  6.4  2.51  31  ...
# 229   3137    2021  Max Scherzer  - - -   36  15  4  5.4  2.46  30  ...
# 175   3137    2022  Max Scherzer    NYM   37  11  5  4.4  2.29  23  ...
# 1219  3137    2023  Max Scherzer  - - -   38  13  6  2.2  3.77  27  ...
# 1178  3137    2020  Max Scherzer    WSN   35   5  4  1.8  3.74  12  ...
#
#       Pit+ FC  Stf+ FS  Loc+ FS  Pit+ FS  Stuff+  Location+  Pitching+  \
# 262       NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 486       NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 256       NaN      NaN      NaN      NaN     NaN        NaN        NaN
# 229      95.0      NaN      NaN      NaN   110.0      103.0      105.0
# ...

# %%
pitching['Team'].unique()
# Out:
# array(['NYM', 'BOS', 'HOU', 'WSN', 'MIL', 'CLE', 'PHI', 'TEX', 'SFG',
#        'TBR', 'MIA', 'ARI', 'TOR', 'LAA', 'NYY', 'ATL', 'LAD', '- - -',
#        'MIN', 'CHW', 'CHC', 'STL', 'CIN', 'SEA', 'COL', 'SDP', 'OAK',
#        'PIT', 'BAL', 'DET', 'KCR'], dtype=object)

# %%
column_names = pitching.columns.tolist()
size_of_sublists = column_names.__len__() // 15
sublist_column = [column_names[i:i + size_of_sublists] for i in range(0, len(column_names), size_of_sublists)]
sublist_column
# Out:
# ['IDfg',
#  'Season',
#  'Name',
#  'Team',
#  'Age',
#  'W',
#  'L',
#  'WAR',
#  'ERA',
#  'G',
#  'GS',
#  'CG',
#  'ShO',
#  'SV',
#  'BS',
#  'IP',
#  'TBF',
#  'H',
#  'R',
#  'ER',
#  'HR',
#  'BB',
#  'IBB',
#  'HBP',
#  'WP',
#  'BK']
